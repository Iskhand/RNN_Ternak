# %% [markdown]
# <a href="https://colab.research.google.com/github/Iskhand/RNN_Ternak/blob/main/Ternak/Ayam_Pedaging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

import tensorflow as tf

# %%
seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
url="https://raw.githubusercontent.com/Iskhand/RNN_Ternak/main/dataset.xlsx"
df = pd.read_excel(url)
df.set_index('Tahun', inplace=True)
df
# Out:
#        Sapi Potong  Sapi Perah   Kambing   Kerbau  Ayam Kampung  \
# Tahun
# 2006      10875125      369008  13789955  2166606     291085191
# 2007      11514871      374067  14470214  2085779     272251141
# 2008      12256604      457577  15147432  1930716     243423389
# 2009      12759838      474701  15815317  1932927     249963499
# 2010      13581571      488488  16619599  1999604     257544104
# 2011      14824373      597213  16946187  1305078     264339634
# 2012      15980696      611940  17905862  1438295     274564427
# 2013      12686239      444266  18500321  1109636     276776576
# 2014      14726875      502516  18639532  1335147     275116120
# 2015      15419719      518649  19012794  1346917     285304304
# 2016      16004097      533933  17847197  1355124     294161691
# 2017      16429102      540441  18208017  1321904     299701400
# 2018      16432945      581522  18306476   894278     300977882
# 2019      16930025      565001  18463115  1133815     301761386
# 2020      17440393      568000  18689711  1154226     305444937
# 2021      17977214      582169  18904347  1143189     306391596
# 2022      17602539      507075  18560835  1088483     308601685
#
#        Ayam Pedaging  Ayam Petelur      Itik     Babi
# Tahun
# 2006       797527446     100201556  32480718  6218202
# 2007       891659346     111488878  35866833  6710757
# 2008       902052418     107955170  39839520  6837528
# 2009      1026378580     111417637  40675995  6974732
# 2010       986871711     105210062  44301804  7476665
# 2011      1177990869     124635794  43487519  7524788
# 2012      1244402017     138717751  49295007  7900362
# 2013      1344191104     146621514  51355088  7598694
# 2014      1443349117     146660415  52682954  7694131
# 2015      1528329183     155007388  45321957  7808086
# 2016      1632567839     161349806  47424151  7903450
# 2017      2922636196     258843681  57557451  8260995
# 2018      3137707479     261932627  59551713  8254108
# 2019      3169805127     263918004  57229088  8520947
# 2020      2919516243     345181214  56569977  7622724
# 2021      2889207954     386125709  56569983  7178088
# 2022      3168325176     378590549  56728470  6748614

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 2006 to 2022
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sapi Potong    17 non-null     int64
#  1   Sapi Perah     17 non-null     int64
#  2   Kambing        17 non-null     int64
#  3   Kerbau         17 non-null     int64
#  4   Ayam Kampung   17 non-null     int64
#  5   Ayam Pedaging  17 non-null     int64
#  6   Ayam Petelur   17 non-null     int64
#  7   Itik           17 non-null     int64
#  8   Babi           17 non-null     int64
# dtypes: int64(9)
# memory usage: 1.3 KB

# %%
plt.figure(figsize=(16, 6))
plt.title("Jumlah Ternak Ayam Pedaging")
plt.plot(df['Ayam Pedaging'])
plt.xlabel('Tahun')
plt.ylabel('Jumlah')
plt.show()

# %%
dataset = df[['Ayam Pedaging']]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.        ],
#        [0.03967997],
#        [0.04406102],
#        [0.09646895],
#        [0.07981539],
#        [0.16037896],
#        [0.18837364],
#        [0.23043831],
#        [0.27223696],
#        [0.3080591 ],
#        [0.35199943],
#        [0.89580944],
#        [0.98646969],
#        [1.        ],
#        [0.89449427],
#        [0.88171824],
#        [0.99937615]])

# %%
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

n_train = train_data.shape[0]
n_test = test_data.shape[0]

print("Jumlah data latih:", n_train)
print("Jumlah data uji:", n_test)
# Out:
# Jumlah data latih: 13
# Jumlah data uji: 4

# %%
def create_dataset(data, time_steps=1):
    x, y = [], []
    for i in range(time_steps, len(data)):
        x.append(data[i-time_steps:i])
        y.append(data[i, 0])
    return np.array(x), np.array(y)

time_steps = 3
x_train, y_train = create_dataset(train_data, time_steps)
x_test, y_test = create_dataset(test_data, time_steps)

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (10, 3, 1)
# (1, 3, 1)

# %%
model = Sequential([
    LSTM(32, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    LSTM(16),
    Dense(8),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mape'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 32)             4352
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 8)                 136
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 7633 (29.82 KB)
# Trainable params: 7633 (29.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=2, validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 14s 553ms/step - loss: 0.1945 - mape: 86.6229 - val_loss: 0.7498 - val_mape: 86.6442
# Epoch 2/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1613 - mape: 63.9835 - val_loss: 0.6040 - val_mape: 77.7631
# Epoch 3/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1280 - mape: 53.3284 - val_loss: 0.4669 - val_mape: 68.3754
# Epoch 4/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1099 - mape: 47.1235 - val_loss: 0.3276 - val_mape: 57.2731
# Epoch 5/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0910 - mape: 54.1765 - val_loss: 0.2074 - val_mape: 45.5718
# Epoch 6/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0715 - mape: 69.3905 - val_loss: 0.1294 - val_mape: 35.9894
# Epoch 7/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0671 - mape: 85.3931 - val_loss: 0.0690 - val_mape: 26.2868
# Epoch 8/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0691 - mape: 104.9300 - val_loss: 0.0280 - val_mape: 16.7410
# Epoch 9/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0652 - mape: 112.3105 - val_loss: 0.0148 - val_mape: 12.1770
# Epoch 10/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0640 - mape: 108.5527 - val_loss: 0.0154 - val_mape: 12.4253
# Epoch 11/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0598 - mape: 100.6897 - val_loss: 0.0104 - val_mape: 10.1845
# Epoch 12/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0580 - mape: 95.2257 - val_loss: 0.0074 - val_mape: 8.6208
# Epoch 13/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0566 - mape: 88.8447 - val_loss: 0.0057 - val_mape: 7.5521
# Epoch 14/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0537 - mape: 83.7715 - val_loss: 8.0798e-04 - val_mape: 2.8443
# Epoch 15/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0513 - mape: 80.6087 - val_loss: 1.3713e-04 - val_mape: 1.1717
# Epoch 16/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0491 - mape: 78.8708 - val_loss: 0.0048 - val_mape: 6.9214
# Epoch 17/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0473 - mape: 79.8185 - val_loss: 0.0310 - val_mape: 17.6260
# Epoch 18/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0440 - mape: 83.5662 - val_loss: 0.0632 - val_mape: 25.1532
# Epoch 19/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0420 - mape: 82.9189 - val_loss: 0.1186 - val_mape: 34.4624
# Epoch 20/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0394 - mape: 81.2395 - val_loss: 0.1798 - val_mape: 42.4286

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
def predict_with_sliding_window(model, data, time_steps):
    predictions = []
    for i in range(time_steps, len(data)):
        x_input = data[i-time_steps:i].reshape((1, time_steps, 1))
        y_pred = model.predict(x_input)
        predictions.append(y_pred[0, 0])
    return np.array(predictions)

test_data_full = scaled_data[train_size-time_steps:]

predictions_full = predict_with_sliding_window(model, test_data_full, time_steps)
predictions_full = scaler.inverse_transform(predictions_full.reshape(-1, 1))

y_test_full = dataset['Ayam Pedaging'].values[train_size:]
# Out:
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
test_df_full = dataset.iloc[train_size:].copy()
test_df_full['Predictions'] = np.nan
test_df_full.iloc[:len(predictions_full), test_df_full.columns.get_loc('Predictions')] = predictions_full.flatten()
print("Data Test dengan Prediksi:")
print(test_df_full)
# Out:
# Data Test dengan Prediksi:
#        Ayam Pedaging   Predictions
# Tahun
# 2019      3169805127  2.592943e+09
# 2020      2919516243  3.203748e+09
# 2021      2889207954  3.264519e+09
# 2022      3168325176  3.196105e+09

# %%
plt.figure(figsize=(16, 6))
plt.plot(dataset.index[train_size:], y_test_full, label='Data Asli (Test)')
plt.plot(dataset.index[train_size:], predictions_full, label='Prediksi (Test)')
plt.title('Data Prediksi vs Data Test')
plt.xlabel('Tahun')
plt.ylabel('Jumlah')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 6))
plt.plot(dataset.index, dataset['Ayam Pedaging'], label='Data Asli')
plt.plot(dataset.index[train_size:], y_test_full, label='Data Asli (Test)')
plt.plot(dataset.index[train_size:], predictions_full, label='Prediksi (Test)')
plt.title('Data Prediksi & Seluruh Data')
plt.xlabel('Tahun')
plt.ylabel('Jumlah')
plt.legend()
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test_full, predictions_full))
mape = mean_absolute_percentage_error(y_test_full, predictions_full.flatten()) * 100

print(f"RMSE: {rmse}")
print(f"MAPE: {mape}")
# Out:
# RMSE: 372554581.4726079
# MAPE: 10.450279157187428

# %%
n_years = 15
last_data = scaled_data[-time_steps:]

future_predictions = []
for _ in range(n_years):
    pred = model.predict(last_data.reshape(1, time_steps, 1))
    future_predictions.append(pred[0, 0])
    last_data = np.append(last_data[1:], pred[0, 0]).reshape(time_steps, 1)

future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

last_year = df.index[-1]
future_years = [last_year + i for i in range(1, n_years + 1)]
future_df = pd.DataFrame(data=future_predictions, index=future_years, columns=['Predicted_Jumlah'])

print(future_df)

plt.figure(figsize=(20, 6))
plt.plot(df['Ayam Pedaging'], label='Actuals')
plt.plot(future_df['Predicted_Jumlah'], label='Future Predictions', linestyle='--')
plt.title(f'Prediksi Jumlah Ternak {n_years} Tahun ke Depan')
plt.xlabel('Tahun')
plt.ylabel('Harga')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
#       Predicted_Jumlah
# 2023      3.125735e+09
# 2024      3.191640e+09
# 2025      3.308866e+09
# 2026      3.330165e+09
# 2027      3.398086e+09
# 2028      3.466144e+09
# 2029      3.507352e+09
# 2030      3.564218e+09
# 2031      3.615395e+09
# 2032      3.658871e+09
# 2033      3.706019e+09
# 2034      3.748897e+09
# 2035      3.788845e+09
# 2036      3.828528e+09
# 2037      3.865383e+09
